# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] =(25,10)
plt.rcParams['figure.dpi'] = 350
plt.rcParams['font.size'] = 20
import pandas as pd
import seaborn as sns

# %%
zen_126 = pd.read_csv('126_88.csv')
zen_137 = pd.read_csv('137.17.csv')
zen_150 = pd.read_csv('150.52.csv')
zen_191 = pd.read_csv('191.50.csv')
zen_242 = pd.read_csv('242.72.csv')

# %%
zen_126
# Out:
#       Current(A)  Voltage(V)
# 0  -1.400000e-08   -0.000357
# 1   9.995070e-04    0.982861
# 2   1.997801e-03    0.989948
# 3   2.996665e-03    0.994262
# 4   3.998310e-03    0.999902
# 5   4.997293e-03    1.013423
# 6   5.995932e-03    1.015525
# 7   6.997301e-03    1.017322
# 8   7.995868e-03    1.018879
# 9   8.997906e-03    1.020272
# 10  9.996977e-03    1.021514
# 11 -1.200000e-08   -0.000319
# 12 -1.200000e-08   -0.986571
# 13 -1.500000e-08   -1.996774
# 14 -1.200000e-08   -2.995244
# 15 -1.200000e-08   -3.993467
# 16 -1.400000e-08   -4.991588
# 17 -9.997310e-04   -5.814605
# 18 -2.000819e-03   -5.815930
# 19 -3.002761e-03   -5.818073
# 20 -4.001685e-03   -5.820216
# 21 -5.000037e-03   -5.822355
# 22 -6.001610e-03   -5.824509
# 23 -7.000212e-03   -5.826653
# 24 -7.999136e-03   -5.828795
# 25 -8.997786e-03   -5.830951
# 26 -9.999613e-03   -5.833110

# %%
sns.lineplot(x='Voltage(V)', y ='Current(A)',data=zen_126, palette='Reds', label='126.88 K',  marker='o')
sns.lineplot(x='Voltage(V)', y ='Current(A)',data=zen_137, palette='Greens', label='150.52 K', marker='*')
sns.lineplot(x='Voltage(V)', y ='Current(A)',data=zen_150, palette='Greens', label='150.52 K', marker='^')
sns.lineplot(x='Voltage(V)', y ='Current(A)',data=zen_191, palette='Greens', label='191.50 K', marker='s')
sns.lineplot(x='Voltage(V)', y ='Current(A)',data=zen_242, palette='Greens', label='242.72 K', marker='D')
plt.grid()
